# %%
import requests
import pandas as pd
from datetime import datetime
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# Access the environment variable
Token_MC_Smart = os.getenv("Token_MC_Smart")

# %%
# API endpoint
url = "https://api.moysklad.ru/api/remap/1.2/report/profit/byproduct"

# Parameters for the request
params = {
    "limit": 1000,  # Maximum number of entities to retrieve
    "offset": 0,     # Offset in the list of entities
    "momentFrom": datetime.now().strftime("%Y-01-01"),  # Beginning of the current year
    "momentTo": datetime.now().strftime("%Y-%m-%d %H:%M:%S")  # Current date and time
}

# Headers for the request
headers = {
    "Authorization": Token_MC_Smart,  # Replace with your access token
    "Content-Type": "application/json"
}

# Make the GET request
response = requests.get(url, headers=headers, params=params)

# Check if the request was successful
if response.status_code == 200:
    # Parse the JSON response
    data = response.json()

    # Display the DataFrame
    print(data)
else:
    print(f"Request failed with status code: {response.status_code}")
    print(response.text)
# Out:
# {'context': {'employee': {'meta': {'href': 'https://api.moysklad.ru/api/remap/1.2/context/employee', 'metadataHref': 'https://api.moysklad.ru/api/remap/1.2/entity/employee/metadata', 'type': 'employee', 'mediaType': 'application/json'}}}, 'meta': {'href': 'https://api.moysklad.ru/api/remap/1.2/report/profit/byproduct?limit=1000&offset=0&momentFrom=2025-01-01&momentTo=2025-06-06+17%3A35%3A43', 'type': 'salesbyproduct', 'mediaType': 'application/json', 'size': 90, 'limit': 1000, 'offset': 0}, 'rows': [{'assortment': {'meta': {'href': 'https://api.moysklad.ru/api/remap/1.2/entity/product/e430aa72-8ada-11ef-0a80-1006000ec7ba', 'metadataHref': 'https://api.moysklad.ru/api/remap/1.2/entity/product/metadata', 'type': 'product', 'mediaType': 'application/json', 'uuidHref': 'https://online.moysklad.ru/app/#good/edit?id=e430a07d-8ada-11ef-0a80-1006000ec7b5'}, 'name': 'Венчик для миксеров KitchenAid', 'code': '5K5A2WW_DM', 'article': '5K5A2WW_DM', 'uom': {'meta': {'href': 'https://api.moysklad.ru/api/remap/1.2/entity/uom/19f1edc0-fc42-4001-94cb-c9ec9c62ec10', 'metadataHref': 'https://api.moysklad.ru/api/remap/1.2/entity/uom/metadata', 'type': 'uom', 'mediaType': 'application/json'}, 'name': 'шт'}}, 'sellQuantity': 190.0, 'sellPrice': 433124.75789473683, 'sellCost': 189755.73684210525, 'sellSum': 82293704, 'sellCostSum': 36053590, 'returnQuantity': 8.0, 'returnPrice': 573699.875, 'returnCost': 199200.0, 'returnSum': 4589599.0, 'returnCostSum': 1593600.0, 'profit': 43244115, 'margin': 1.2549079381624892, 'salesMargin': 0.5565229147160243}, {'assortment': {'meta': {'href': 'https://api.moysklad.ru/api/remap/1.2/entity/product/b948c4af-8ada-11ef-0a80-1569000f85d9', 'metadataHref': 'https://api.moysklad.ru/api/remap/1.2/entity/product/metadata', 'type': 'product', 'mediaType': 'application/json', 'uuidHref': 'https://online.moysklad.ru/app/#good/edit?id=b948b7f9-8ada-11ef-0a80-1569000f85d4'}, 'name': 'Лопатка с гибким силиконовым ребром для миксеров KitchenAid', 'code': 'KFE5T_DM', 'article': 'KFE5T_DM', 'uom': {'meta': {'href': 'https://api.moysklad.ru/api/remap/1.2/entity/uom/19f1edc0-fc42-4001-94cb-c9ec9c62ec10', 'metadataHref': 'https://api.moysklad.ru/api/remap/1.2/entity/uom/metadata', 'type': 'uom', 'mediaType': 'application/json'}, 'name': 'шт'}}, 'sellQuantity': 75.0, 'sellPrice': 215062.34666666668, 'sellCost': 164683.6, 'sellSum': 16129676, 'sellCostSum': 12351270, 'returnQuantity': 3.0, 'returnPrice': 524735.0, 'returnCost': 164700.0, 'returnSum': 1574205.0, 'returnCostSum': 494100.0, 'profit': 2698301.0, 'margin': 0.22756703328028527, 'salesMargin': 0.18538053492051199}, {'assortment': {'meta': {'href': 'https://api.moysklad.ru/api/remap/1.2/entity/product/a9689fc0-1f3d-11ef-0a80-054d001b247b', 'metadataHref': 'https://api.moysklad.ru/api/remap/1.2/entity/product/metadata', 'type': 'product', 'mediaType': 'application/json', 'uuidHref': 'https://online.moysklad.ru/app/#good/edit?id=a9689274-1f3d-11ef-0a80-054d001b2474'}, 'name': 'Машинка для стрижки волос Braun HC5350', 'code': 'Б0062960', 'article': '742413', 'uom': {'meta': {'href': 'https://api.moysklad.ru/api/remap/1.2/entity/uom/19f1edc0-fc42-4001-94cb-c9ec9c62ec10', 'metadataHref': 'https://api.moysklad.ru/api/remap/1.2/entity/uom/metadata', 'type': 'uom', 'mediaType': 'application/json'}, 'name': 'шт'}}, 'sellQuantity': 203.0, 'sellPrice': 2817119.793103448, 'sellCost': 2384410.6354679805, 'sellSum': 571875318, 'sellCostSum': 484035359, 'returnQuantity': 0.0, 'returnPrice': 0.0, 'returnCost': 0.0, 'returnSum': 0.0, 'returnCostSum': 0.0, 'profit': 87839959, 'margin': 0.18147426085043517, 'salesMargin': 0.1535998428944262}, {'assortment': {'meta': {'href': 'https://api.moysklad.ru/api/remap/1.2/entity/product/caec172b-baca-11ee-0a80-00a0000a83c6', 'metadataHref': 'https://api.moysklad.ru/api/remap/1.2/entity/product/metadata', 'type': 'product', 'mediaType': 'application/json', 'uuidHref': 'https://online.moysklad.ru/app/#good/edit?id=caec0785-baca-11ee-0a80-00a0000a83bf'},  ...

# %%
import pandas as pd


def flatten_product_row(row):
    """Flatten a single row of product data, handling missing keys."""
    assortment = row.get('assortment', {})
    meta = assortment.get('meta', {})
    uom = assortment.get('uom', {}).get('name', None)
    
    flat_row = {
        # Product info
        'product_name': assortment.get('name'),
        'product_code': assortment.get('code'),
        'product_article': assortment.get('article'),
        'product_uom': uom,
        'product_href': meta.get('href'),
        'product_uuid': meta.get('uuidHref', '').split('id=')[-1] if meta.get('uuidHref') else None,
        
        # Sales metrics
        'sell_quantity': row.get('sellQuantity'),
        'sell_price': row.get('sellPrice'),
        'sell_sum': row.get('sellSum'),
        'sell_cost_sum': row.get('sellCostSum'),
        'return_quantity': row.get('returnQuantity'),
        'return_sum': row.get('returnSum'),
        'profit': row.get('profit'),
        'margin': row.get('margin'),
        'sales_margin': row.get('salesMargin')
    }
    return flat_row

# Process all rows
rows = [flatten_product_row(row) for row in data['rows']]

# Create DataFrame
df = pd.DataFrame(rows)

# Display the DataFrame
df
# Out:
#                                          product_name   product_code  \
# 0                      Венчик для миксеров KitchenAid     5K5A2WW_DM
# 1   Лопатка с гибким силиконовым ребром для миксер...       KFE5T_DM
# 2              Машинка для стрижки волос Braun HC5350       Б0062960
# 3   Набор электрических зубных щеток Oral-B Vitali...       80368953
# 4   Насадка для стрижки бороды Braun XT20 Black дл...  7500435205979
# ..                                                ...            ...
# 85        Эпилятор Braun Silk-epil 5 SE5-011 тип 5392  7500435225052
# 86   Эпилятор Braun Silk-epil 5 SE5-050 FLMG тип 5392  7500435225038
# 87   Эпилятор Braun Silk-epil 7 SE7-000 FLMG тип 5392  7500435225151
# 88  Эпилятор Braun Silk-epil 9 SES9-011 3D тип 538...  7500435225328
# 89  Эпилятор Braun Silk-epil 9 SES9-030 FLMG тип 5380  7500435225229
#
#    product_article product_uom  \
# 0       5K5A2WW_DM          шт
# 1         KFE5T_DM          шт
# 2           742413          шт
# 3         80368953          шт
# 4           742542          шт
# ..             ...         ...
# 85          742625          шт
# 86          742704          шт
# 87          742623          шт
# 88          742702          шт
# 89          742701          шт
#
#                                          product_href  \
# 0   https://api.moysklad.ru/api/remap/1.2/entity/p...
# 1   https://api.moysklad.ru/api/remap/1.2/entity/p...
# 2   https://api.moysklad.ru/api/remap/1.2/entity/p...
# 3   https://api.moysklad.ru/api/remap/1.2/entity/p...
# 4   https://api.moysklad.ru/api/remap/1.2/entity/p...
# ..                                                ...
# 85  https://api.moysklad.ru/api/remap/1.2/entity/p...
# 86  https://api.moysklad.ru/api/remap/1.2/entity/p...
# 87  https://api.moysklad.ru/api/remap/1.2/entity/p...
# 88  https://api.moysklad.ru/api/remap/1.2/entity/p...
# 89  https://api.moysklad.ru/api/remap/1.2/entity/p...
#
#                             product_uuid  sell_quantity    sell_price  \
# 0   e430a07d-8ada-11ef-0a80-1006000ec7b5          190.0  4.331248e+05
# 1   b948b7f9-8ada-11ef-0a80-1569000f85d4           75.0  2.150623e+05
# 2   a9689274-1f3d-11ef-0a80-054d001b2474          203.0  2.817120e+06
# 3   caec0785-baca-11ee-0a80-00a0000a83bf            2.0  1.893253e+06
# 4   a97b2dab-1f3d-11ef-0a80-054d001b248c            1.0  1.131729e+06
# ..                                   ...            ...           ...
# 85  a9c7e2ea-1f3d-11ef-0a80-054d001b24ec          259.0  3.819924e+06
# 86  a9efa4ad-1f3d-11ef-0a80-054d001b251c          316.0  4.402637e+06
# 87  a9aaf7ae-1f3d-11ef-0a80-054d001b24c8          507.0  4.636852e+06
# 88  aa0372a2-1f3d-11ef-0a80-054d001b2534          424.0  6.421582e+06
# 89  a9fa5649-1f3d-11ef-0a80-054d001b2528          276.0  5.403385e+06
#
#         sell_sum  sell_cost_sum  return_quantity  return_sum       profit  \
# 0   8.229370e+07   3.605359e+07              8.0   4589599.0   43244115.0
# 1   1.612968e+07   1.235127e+07              3.0   1574205.0    2698301.0
# 2   5.718753e+08   4.840354e+08              0.0         0.0   87839959.0
# 3   3.786505e+06   7.286000e+06              0.0         0.0   -3499495.0
# 4   1.131729e+06   6.352000e+05              0.0         0.0     496529.0
# ..           ...            ...              ...         ...          ...
# 85  9.893604e+08   6.934771e+08              1.0   4678702.0  293865599.0
# 86  1.391233e+09   8.917406e+08              1.0   5497888.0  497233739.0
# 87  2.350884e+09   1.738331e+09              4.0  23105264.0  603084636.0
# 88  2.722751e+09   2.288610e+09              2.0  17730224.0  427075554.0
# 89  1.491334e+09   9.497819e+08              0.0         0.0  541552349.0
#
#       margin  sales_margin
# 0   1.254908      0.556523
# 1   0.227567      0.185381
# 2   0.181474      0.153600
# 3  -0.480304     -0.924202
# 4   0.781689      0.438735
# ..       ...           ...
# 85  0.425389      0.298437
# 86  0.559632      0.358823
# 87  0.349676      0.259082
# 88  0.187483      0.157883
# 89  0.570186      0.363133
#
# [90 rows x 15 columns]
